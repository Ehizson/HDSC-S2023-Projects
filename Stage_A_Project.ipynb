# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehizson/HDSC-S2023-Projects/blob/main/Stage_A_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUCTION TO PYTHON FOR MACHINE LEARNING**

# %% [markdown]
# ## **Michael Godwin Ehizojie**
#
# ## **ID: 1603dc278b81f000**

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading dataset

data = pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin1')
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#3
#sum of stock variation Y2014

data.groupby("Element")['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
#6
#sum of unique countries

data.groupby("Area").count().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Algeria to Zimbabwe
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     49 non-null     int64
#  1   Item Code     49 non-null     int64
#  2   Item          49 non-null     int64
#  3   Element Code  49 non-null     int64
#  4   Element       49 non-null     int64
#  5   Unit          49 non-null     int64
#  6   Y2014         49 non-null     int64
#  7   Y2015         49 non-null     int64
#  8   Y2016         49 non-null     int64
#  9   Y2017         49 non-null     int64
#  10  Y2018         49 non-null     int64
# dtypes: int64(11)
# memory usage: 4.6+ KB

# %%
#7
#correlation

data.corr()
# Out:
# <ipython-input-9-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
#10
#sum aggregation of wine Y2015 & Y2018

data.groupby("Item").sum()
# Out:
# <ipython-input-10-864f06e73408>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Item").sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...

# %%
#11
#sum of Processing Y2017

data.groupby("Element").sum()
# Out:
# <ipython-input-11-b39c18b9e72e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Element").sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
#14&15

data.groupby("Area")[['Y2017', 'Area']].count()
# Out:
#                              Y2017  Area
# Area
# Algeria                       1279  1313
# Angola                        1407  1424
# Benin                         1253  1285
# Botswana                      1368  1378
# Burkina Faso                  1383  1409
# Cabo Verde                    1193  1260
# Cameroon                      1441  1460
# Central African Republic      1262  1344
# Chad                          1281  1343
# Comoros                         45    45
# Congo                         1395  1413
# Côte d'Ivoire                 1454  1467
# Djibouti                      1061  1095
# Egypt                         1458  1488
# Eswatini                      1251  1284
# Ethiopia                      1428  1447
# Ethiopia PDR                    39    39
# Gabon                         1206  1245
# Gambia                        1116  1168
# Ghana                         1333  1354
# Guinea                        1383  1410
# Guinea-Bissau                 1076  1128
# ...

# %%
#18
#statistical description

data['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
#19
#checking for missing data in Y2014

data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
